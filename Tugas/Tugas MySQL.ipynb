# %% [markdown]
# # Tugas MySQL 1

# %%
import pymysql
import pandas as pd

host = '127.0.0.1'
port = "3306"
user = 'root'
password = ''
database = 'classicmodels'

conn = pymysql.connect(
    host=host,
    port=int(port),
    user=user,
    passwd=password,
    db=database,
    charset='utf8mb4')

def run(sql):
    df = pd.read_sql_query(sql,conn)
    return df

# %%
run("SHOW TABLES")
# Out:
#   Tables_in_classicmodels
# 0               customers
# 1               employees
# 2                 offices
# 3            orderdetails
# 4                  orders
# 5                payments
# 6            productlines
# 7                products

# %%
#1. Prepare a list of offices sorted by country, state, city.
run("SELECT * FROM offices ORDER BY country")
# Out:
#   officeCode           city             phone              addressLine1  \
# 0          6         Sydney   +61 2 9264 2451     5-11 Wentworth Avenue
# 1          4          Paris   +33 14 723 4404  43 Rue Jouffroy D'abbans
# 2          5          Tokyo   +81 33 224 5000               4-1 Kioicho
# 3          7         London  +44 20 7877 2041       25 Old Broad Street
# 4          1  San Francisco   +1 650 219 4782         100 Market Street
# 5          2         Boston   +1 215 837 0825          1550 Court Place
# 6          3            NYC   +1 212 555 3000      523 East 53rd Street
#
#   addressLine2       state    country postalCode territory
# 0     Floor #2        None  Australia   NSW 2010      APAC
# 1         None        None     France      75017      EMEA
# 2         None  Chiyoda-Ku      Japan   102-8578     Japan
# 3      Level 7        None         UK   EC2N 1HN      EMEA
# 4    Suite 300          CA        USA      94080        NA
# ...

# %%
#2. How many employees are there in the company?
run("SELECT SUM(employeeNumber) FROM employees")
# Out:
#    SUM(employeeNumber)
# 0              30714.0

# %%
#3. What is the total of payments received?
run("SELECT SUM(amount) FROM payments")
# Out:
#    SUM(amount)
# 0   8853839.23

# %%
#4. List the product lines that contain 'Cars'.
run("SELECT DISTINCT productLine FROM products WHERE productLine LIKE '%cars%'")
# Out:
#     productLine
# 0  Classic Cars
# 1  Vintage Cars

# %%
#5. Report total payments for October 28, 2004.
run("SELECT amount FROM payments WHERE paymentDate = '2004-10-28'")
# Out:
#      amount
# 0  47411.33

# %%
#6. Report those payments greater than \$100,000.
run("SELECT * FROM payments WHERE amount > 100000")
# Out:
#    customerNumber checkNumber paymentDate     amount
# 0             124    AE215433  2005-03-05  101244.59
# 1             124    KI131716  2003-08-15  111654.40
# 2             141     ID10962  2004-12-31  116208.40
# 3             141    JE105477  2005-03-18  120166.58
# 4             148    KM172879  2003-12-26  105743.00

# %%
#7. List the products in each product line.
run("SELECT productName,productLine,buyPrice FROM products ORDER BY productLine")
# Out:
#                                      productName       productLine  buyPrice
# 0                       1952 Alpine Renault 1300      Classic Cars     98.58
# 1                            1972 Alfa Romeo GTA      Classic Cars     85.68
# 2                         1962 LanciaA Delta 16V      Classic Cars    103.42
# 3                              1968 Ford Mustang      Classic Cars     95.34
# 4                              2001 Ferrari Enzo      Classic Cars     95.59
# 5                             1969 Corvair Monza      Classic Cars     89.14
# 6                             1968 Dodge Charger      Classic Cars     75.16
# 7                               1969 Ford Falcon      Classic Cars     83.05
# 8                        1970 Plymouth Hemi Cuda      Classic Cars     31.92
# 9                             1969 Dodge Charger      Classic Cars     58.73
# 10                               1993 Mazda RX-7      Classic Cars     83.51
# ...

# %%
#8. How many products in each product line?
run("SELECT productLine,COUNT(productName) AS JumlahProduk FROM products GROUP BY productLine")
# Out:
#         productLine  JumlahProduk
# 0      Classic Cars            38
# 1       Motorcycles            13
# 2            Planes            12
# 3             Ships             9
# 4            Trains             3
# 5  Trucks and Buses            11
# 6      Vintage Cars            24

# %%
#9. What is the minimum payment received?
run("SELECT MIN(amount) FROM payments")
# Out:
#    MIN(amount)
# 0       615.45

# %%
#10. List all payments greater than twice the average payment.
run("SELECT * FROM payments WHERE amount > (SELECT AVG(amount)*2 FROM payments)")
# Out:
#     customerNumber checkNumber paymentDate     amount
# 0              114    MA765515  2004-12-15   82261.22
# 1              124    AE215433  2005-03-05  101244.59
# 2              124    BG255406  2004-08-28   85410.87
# 3              124     ET64396  2005-04-16   83598.04
# 4              124    KI131716  2003-08-15  111654.40
# 5              141     ID10962  2004-12-31  116208.40
# 6              141    IN446258  2005-03-25   65071.26
# 7              141    JE105477  2005-03-18  120166.58
# 8              148    KM172879  2003-12-26  105743.00
# 9              167    GN228846  2003-12-03   85024.46
# 10             239    NQ865547  2004-03-15   80375.24
# 11             321     DJ15149  2003-11-03   85559.12
# 12             323    AL493079  2005-05-23   75020.13

# %%
#11. What is the average percentage markup of the MSRP on buyPrice?
run("SELECT AVG(((MSRP-buyPrice)/buyPrice)*100) FROM products ")
# Out:
#    AVG(((MSRP-buyPrice)/buyPrice)*100)
# 0                            88.702392

# %%
#12. How many distinct products does ClassicModels sell?
run("SELECT COUNT(DISTINCT productName) FROM products")
# Out:
#    COUNT(DISTINCT productName)
# 0                          110

# %%
#13. Report the name and city of customers who don't have sales representatives?
run("SELECT customerName, city FROM customers WHERE salesRepEmployeeNumber IS Null")
# Out:
#                       customerName              city
# 0               Havel & Zbyszek Co          Warszawa
# 1                Porto Imports Co.            Lisboa
# 2       Asian Shopping Network, Co         Singapore
# 3                  Natürlich Autos         Cunewalde
# 4                    ANG Resellers            Madrid
# 5         Messner Shopping Network         Frankfurt
# 6                Franken Gifts, Co           München
# 7                BG&E Collectables          Fribourg
# 8                 Schuyler Imports         Amsterdam
# 9                 Der Hund Imports            Berlin
# 10       Cramer Spezialitäten, Ltd       Brandenburg
# 11           Asian Treasures, Inc.              Cork
# 12            SAR Distributors, Co          Hatfield
# 13                 Kommission Auto           Münster
# 14          Lisboa Souveniers, Inc            Lisboa
# 15  Stuttgart Collectable Exchange         Stuttgart
# 16        Feuer Online Stores, Inc           Leipzig
# ...

# %%
#14. What are the names of executives with VP or Manager in their title? Use the CONCAT function to combine the employee's first name and last name into a single field for reporting.
run("""
    SELECT 
        CONCAT(lastName,' ',firstName ) 
        AS fullName 
    FROM employees
    WHERE jobTitle LIKE '%VP%' OR jobTitle LIKE '%Manager%' 
    """)
# Out:
#             fullName
# 0     Patterson Mary
# 1      Firrelli Jeff
# 2  Patterson William
# 3      Bondur Gerard
# 4        Bow Anthony

# %%
#15. Which orders have a value greater than $5,000?
run("SELECT orderNumber,productCode FROM orderdetails WHERE priceEach*quantityOrdered > 5000" )
# Out:
#      orderNumber productCode
# 0          10103    S10_1949
# 1          10103    S10_4962
# 2          10105    S10_4757
# 3          10105    S12_1108
# 4          10105    S24_2011
# 5          10108    S12_1099
# 6          10108    S18_4721
# 7          10108    S24_3856
# 8          10109    S18_1984
# 9          10109    S18_3232
# 10         10109    S18_3685
# 11         10110    S18_1749
# 12         10110    S18_2795
# 13         10110    S24_2887
# 14         10112    S10_1949
# 15         10114    S18_3232
# 16         10115    S12_4473
# 17         10115    S18_2238
# 18         10117    S12_1108
# 19         10117    S12_3148
# 20         10117    S12_3891
# 21         10119    S10_4757
# 22         10119    S18_1662
# 23         10120    S10_4698
# 24         10121    S12_2823
# 25         10122    S12_1099
# 26         10122    S24_3856
# 27         10123    S18_2870
# 28         10126    S10_1949
# 29         10126    S18_4600
# ..           ...         ...
# ...
